# %%
import pandas as pd
import pickle
nombre_archivo='P1_ejercicio2_modelo.sav'
modelo_produccion = pickle.load(open(nombre_archivo, 'rb'))

# %% [markdown]
# ### Datos:

# %%
df=pd.read_csv('df_X_reales.csv')

# %%
df
# Out:
#            x1        x2        x3        x4
# 0    0.610848 -0.540147 -0.609123  0.076566
# 1   -0.439064  0.054173 -0.990305 -0.454106
# 2    0.887991  0.493949  0.484646  0.670971
# 3    0.760949  0.323469 -0.756437  0.321687
# 4    0.361203  1.083199 -0.739142  0.287214
# ..        ...       ...       ...       ...
# 195  0.086152 -0.466557 -0.232410 -0.011311
# 196 -1.413128 -0.213519 -0.861650  0.415804
# 197 -1.147237  1.520166 -0.586616  0.154290
# 198  0.470264 -1.111430  1.069919 -0.909327
# 199  1.094110 -0.166797  0.796668 -0.837083
#
# [200 rows x 4 columns]

# %% [markdown]
# ### Pronosticamos los valores de Y:

# %%
ypred=modelo_produccion.predict(df)

# %%
ypred
# Out:
# array([[ -45.3297495 ],
#        [-104.77478466],
#        [  87.81399422],
#        [ -31.95061189],
#        [ -26.51953007],
#        [ -59.45750102],
#        [ 145.0369138 ],
#        [  59.48331947],
#        [ 156.56476283],
#        [-115.94400219],
#        [ -82.46962393],
#        [  35.42692219],
#        [ 151.17995985],
#        [ -60.0878623 ],
#        [-181.90186104],
#        [  48.6110533 ],
#        [  12.0728985 ],
#        [ -63.91780461],
#        [  12.2365147 ],
#        [-122.93760527],
#        [ -16.55878758],
#        [  68.04685302],
#        [  17.33916915],
#        [-179.08550874],
#        [-162.02528886],
#        [ -58.2502661 ],
#        [  30.83617673],
#        [  56.01952523],
#        [  11.28876089],
#        [ -40.43239654],
#        [ -85.47783482],
#        [ -10.01645371],
#        [ -61.87149134],
#        [ -76.43392421],
#        [  48.19239496],
#        [ -86.53359533],
#        [  49.40149544],
#        [  10.19431673],
# ...

# %%
ypred= pd.DataFrame(ypred,columns=['ypred'])
ypred.to_csv('Morales_Lucas.csv',index=False)

# %%
ypred
# Out:
#           ypred
# 0    -45.329749
# 1   -104.774785
# 2     87.813994
# 3    -31.950612
# 4    -26.519530
# ..          ...
# 195  -25.593011
# 196  -84.560651
# 197  -38.424329
# 198   45.698829
# 199   52.223917
#
# [200 rows x 1 columns]
